# %% [markdown]
# <a href="https://colab.research.google.com/github/samantha-olinsky/MA322-Python/blob/main/EDA_Lab_cos_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# we always need to import the necessary packages we'll need
import pandas as pd
import matplotlib.pyplot as plt

# bring in the dataset
cos = pd.read_csv('https://raw.githubusercontent.com/mlhwang/ma322/master/cosmetic_sales.csv')

# double check by printing the dataframe
print(cos)
# Out:
#      salesperson  year     month  ... units_sold order_amount  cost
# 0          Betsy  2004     April  ...          8          288   227
# 1       Hallagan  2004     March  ...        151          448   320
# 2         Ashley  2005  February  ...        416          402   347
# 3       Hallagan  2006       May  ...        202          650   561
# 4          Zaret  2004      June  ...        167          347   219
# ...          ...   ...       ...  ...        ...          ...   ...
# 1886      Ashley  2005  February  ...         95          435   281
# 1887     Colleen  2005  November  ...        114          514   404
# 1888       Zaret  2004   January  ...        202          659   546
# 1889    Hallagan  2006  November  ...        482          410   354
# 1890    Cristina  2006      June  ...        225          463   382
#
# [1891 rows x 8 columns]

# %%
print(cos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1891 entries, 0 to 1890
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   salesperson   1891 non-null   object
#  1   year          1891 non-null   int64
#  2   month         1891 non-null   object
#  3   dept          1891 non-null   object
#  4   location      1891 non-null   object
#  5   units_sold    1891 non-null   int64
#  6   order_amount  1891 non-null   int64
#  7   cost          1891 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 118.3+ KB
# None

# %% [markdown]
# ### Lab Question 1:
# a. 1891 "entries" (examples/observations)
#
# b. Yes! It is structured in a matrix form in a dataframe in Python.
#
# c. List of features and their type.
# * **salesperson** *categorical*
# * **year** *numeric*
# * **month** *categorical*
# * **dept** *categorical*
# * **location** *categorical*
# * **units_sold** *numeric*
# * **order_amount** *numeric*
# * **cost** *numeric*

# %% [markdown]
# ### Question 2:

# %%
print(pd.crosstab(index=cos['salesperson'], columns='count'))  # 2a.
# Out:
# col_0        count
# salesperson
# Ashley         197
# Betsy          217
# Cici           230
# Colleen        206
# Cristina       207
# Emilee         203
# Hallagan       200
# Jen            217
# Zaret          214

# %%
# 2b
rel_freq_tab = pd.crosstab(index=cos['dept'], columns='count')
print(rel_freq_tab/rel_freq_tab.sum())
# Out:
# col_0          count
# dept
# eye liner   0.230566
# foundation  0.225278
# lip gloss   0.217874
# lipstick    0.109466
# mascara     0.216816

# %%
print(cos['month'].plot.bar())
# won't work because the y-axis variable are categorical, not numeric
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-b46b73913c1d> in <module>()
# ----> 1 print(cos['month'].plot.bar())
#       2 # won't work because the y-axis variable are categorical, not numeric
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1105         other axis represents a measured value.
#    1106         """
# -> 1107         return self(kind="bar", x=x, y=y, **kwargs)
#    1108
#    1109     @Appender(
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ...

# %%
# 2c
# so first we need a frequency table to count
freq_month = pd.crosstab(index=cos['month'], columns="count")

# and then we'll put that frequency calculation into a bar plot
print(freq_month.plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# 2d
freq_dept = pd.crosstab(index=cos['dept'], columns='count')
print(freq_dept.plot.pie(y="count"))
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# ### Question 3:

# %%
print(cos['order_amount'].plot.hist())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(cos['order_amount'].plot.box())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(cos['units_sold'].plot.hist())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(cos['units_sold'].plot.box())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# 3b

import statistics

print("The mean of order amounts is:", cos['order_amount'].mean())
print("The mean of units sold is:", cos['units_sold'].mean())
print("The median of order amounts is:", cos['order_amount'].median())
print("The median of units sold is:", cos['units_sold'].median())
print("The standard deviation of order amounts is:", statistics.stdev(cos['order_amount']))
print("The standard deviation of units sold is:", statistics.stdev(cos['units_sold']))
# Out:
# The mean of order amounts is: 477.63405605499736
# The mean of units sold is: 182.69857218402962
# The median of order amounts is: 475.0
# The median of units sold is: 167.0
# The standard deviation of order amounts is: 94.79517537002553
# The standard deviation of units sold is: 103.86156381026478

# %% [markdown]
# ### Question 4:

# %%
print(cos.groupby(['salesperson'])['order_amount'].mean())
# Out:
# salesperson
# Ashley      469.289340
# Betsy       481.198157
# Cici        482.386957
# Colleen     476.917476
# Cristina    483.893720
# Emilee      473.339901
# Hallagan    479.350000
# Jen         467.023041
# Zaret       484.457944
# Name: order_amount, dtype: float64

# %% [markdown]
# ### 4a.
#
# The sales person with the **highest** mean for `order_amount` is: **Zaret**.
#
# The sales person with the **lowest** mean for `order_amount` is: **Jen**.

# %%
print(cos.groupby(['location'])['order_amount'].mean())
# Out:
# location
# east       477.604265
# midwest    477.673522
# south      474.341414
# west       480.415385
# Name: order_amount, dtype: float64

# %% [markdown]
# ### 4b.
#
# The location with the **highest** mean for `order_amount` is: **west**.

# %%
print(cos.groupby(['month'])['order_amount'].var())
# Out:
# month
# April         9275.127707
# August        7925.458172
# December      9300.111839
# February      9543.024461
# January       9962.445592
# July          8920.599425
# June          9002.546123
# March         8620.486313
# May           9637.861586
# November      8101.104696
# October      10571.029958
# September     8335.288492
# Name: order_amount, dtype: float64

# %% [markdown]
# ### 4c.
#
# The month with the **highest** variance for `order_amount` is: **October**.

# %%
# 4d
print(cos.plot.scatter(x='order_amount', y='units_sold'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# 4e
print(pd.crosstab(index=cos['location'], columns=cos['dept']))
# Out:
# dept      eye liner  foundation  lip gloss  lipstick  mascara
# location
# east            105          97         91        41       88
# midwest          94          77         75        47       96
# south           109         128        112        51       95
# west            128         124        134        68      131

# %% [markdown]
# ### Question 5:

# %%
print(plt.scatter(x=cos['order_amount'], y=cos['units_sold'], c=cos['location'].map({'east':'blue', 'midwest': 'red', 'south':'yellow', 'west':'green'})))
